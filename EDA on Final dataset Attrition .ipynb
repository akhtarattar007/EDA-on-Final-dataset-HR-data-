# %%
# Importing  liabraries 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("dark")

# %%
# Importing the data or file.

path = "/content/drive/MyDrive/Colab Notebooks/digikull assignment/digikull datasets/Final dataset Attrition (1) (1).csv"
df = pd.read_csv(path)

# %%
# Show the first 5 rows of Data

df.head()
# Out:
#    Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 0   37       Yes  Travel_Rarely  Research & Development                 2
# 1   21        No  Travel_Rarely  Research & Development                15
# 2   45        No  Travel_Rarely  Research & Development                 6
# 3   23        No  Travel_Rarely                   Sales                 2
# 4   22        No  Travel_Rarely  Research & Development                15
#
#    Gender  JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0    Male               2         1  Laboratory Technician                3
# 1    Male               3         1     Research Scientist                4
# 2    Male               3         3      Research Director                1
# 3    Male               3         1   Sales Representative                1
# 4  Female               3         1  Laboratory Technician                4
#
# ...

# %%
# Show the last 5 rows of Data

df.tail()
# Out:
#       Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 1465   52        No  Travel_Rarely                   Sales                 3
# 1466   55        No  Travel_Rarely  Research & Development                 1
# 1467   55        No  Travel_Rarely                   Sales                26
# 1468   58        No  Travel_Rarely                   Sales                10
# 1469   58       Yes  Travel_Rarely  Research & Development                23
#
#       Gender  JobInvolvement  JobLevel                    JobRole  \
# 1465    Male               2         4                    Manager
# 1466    Male               3         5                    Manager
# 1467    Male               2         5                    Manager
# 1468    Male               3         4            Sales Executive
# 1469  Female               3         3  Healthcare Representative
#
#       JobSatisfaction  ... Date_of_Hire  Date_of_termination  \
# ...

# %%
# Show the columns we have in Data

df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Gender', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Higher_Education',
#        'Date_of_Hire', 'Date_of_termination', 'Status_of_leaving',
#        'Mode_of_work', 'Leaves', 'Absenteeism', 'Work_accident',
#        'Source_of_Hire', 'Job_mode', 'Unnamed: 32'],
#       dtype='object')

# %%
# show the shape of the data.

df.shape
# Out:
# (1470, 33)

# %%
# Show the Column datatype, non-null value count

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   Attrition                1470 non-null   object
#  2   BusinessTravel           1470 non-null   object
#  3   Department               1470 non-null   object
#  4   DistanceFromHome         1470 non-null   int64
#  5   Gender                   1470 non-null   object
#  6   JobInvolvement           1470 non-null   int64
#  7   JobLevel                 1470 non-null   int64
#  8   JobRole                  1470 non-null   object
#  9   JobSatisfaction          1470 non-null   int64
#  10  MaritalStatus            1470 non-null   object
#  11  MonthlyIncome            1470 non-null   int64
#  12  NumCompaniesWorked       1470 non-null   int64
#  13  OverTime                 1470 non-null   object
# ...

# %%
# show some statistics info  about dataset.

df.describe().T
# Out:
#                           count         mean          std     min     25%  \
# Age                      1470.0    36.923810     9.135373    18.0    30.0
# DistanceFromHome         1470.0     9.192517     8.106864     1.0     2.0
# JobInvolvement           1470.0     2.729932     0.711561     1.0     2.0
# JobLevel                 1470.0     2.063946     1.106940     1.0     1.0
# JobSatisfaction          1470.0     2.728571     1.102846     1.0     2.0
# MonthlyIncome            1470.0  6502.931293  4707.956783  1009.0  2911.0
# NumCompaniesWorked       1470.0     2.693197     2.498009     0.0     1.0
# PercentSalaryHike        1470.0    15.209524     3.659938    11.0    12.0
# PerformanceRating        1470.0     3.153741     0.360824     3.0     3.0
# StockOptionLevel         1470.0     0.793878     0.852077     0.0     0.0
# TotalWorkingYears        1470.0    11.279592     7.780782     0.0     6.0
# TrainingTimesLastYear    1470.0     2.799320     1.289271     0.0     2.0
# ...

# %%
df.isnull()
# Out:
#         Age  Attrition  BusinessTravel  Department  DistanceFromHome  Gender  \
# 0     False      False           False       False             False   False
# 1     False      False           False       False             False   False
# 2     False      False           False       False             False   False
# 3     False      False           False       False             False   False
# 4     False      False           False       False             False   False
# ...     ...        ...             ...         ...               ...     ...
# 1465  False      False           False       False             False   False
# 1466  False      False           False       False             False   False
# 1467  False      False           False       False             False   False
# 1468  False      False           False       False             False   False
# 1469  False      False           False       False             False   False
#
# ...

# %%
# Checking null values and sum it.

df.isnull().sum()
# Out:
# Age                           0
# Attrition                     0
# BusinessTravel                0
# Department                    0
# DistanceFromHome              0
# Gender                        0
# JobInvolvement                0
# JobLevel                      0
# JobRole                       0
# JobSatisfaction               0
# MaritalStatus                 0
# MonthlyIncome                 0
# NumCompaniesWorked            0
# OverTime                      0
# PercentSalaryHike             0
# PerformanceRating             0
# StockOptionLevel              0
# TotalWorkingYears             0
# TrainingTimesLastYear         0
# YearsAtCompany                0
# YearsSinceLastPromotion       0
# YearsWithCurrManager          0
# Higher_Education              0
# Date_of_Hire                  0
# Date_of_termination        1470
# Status_of_leaving             0
# Mode_of_work                  0
# Leaves                        0
# Absenteeism                   0
# ...

# %% [markdown]
# ### From the above cell we came to knw that 'unnamed: 32' is a column which contains all the values null so we can remove that column as it will not be helpful in EDA. On the other hand 'Date_of_termination' column also has all the values NaN or null but we need to keep it because of further data could be added by user at the time of employee termination.

# %%
# checking duplicate values in dataframe

df.duplicated().sum()
# Out:
# 0

# %%
# checking unique values in data
df.nunique()
# Out:
# Age                          43
# Attrition                     2
# BusinessTravel                3
# Department                    3
# DistanceFromHome             29
# Gender                        2
# JobInvolvement                4
# JobLevel                      5
# JobRole                       9
# JobSatisfaction               4
# MaritalStatus                 3
# MonthlyIncome              1349
# NumCompaniesWorked           10
# OverTime                      2
# PercentSalaryHike            15
# PerformanceRating             2
# StockOptionLevel              4
# TotalWorkingYears            40
# TrainingTimesLastYear         7
# YearsAtCompany               37
# YearsSinceLastPromotion      16
# YearsWithCurrManager         18
# Higher_Education              4
# Date_of_Hire               1112
# Date_of_termination           0
# Status_of_leaving             5
# Mode_of_work                  2
# Leaves                        6
# Absenteeism                   4
# ...

# %%
# Droping Unnamed: 32 column (contains all null values)
df=df.drop(['Unnamed: 32'], axis = 1)
df.head(2)
# Out:
#    Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 0   37       Yes  Travel_Rarely  Research & Development                 2
# 1   21        No  Travel_Rarely  Research & Development                15
#
#   Gender  JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0   Male               2         1  Laboratory Technician                3
# 1   Male               3         1     Research Scientist                4
#
#    ... Higher_Education  Date_of_Hire  Date_of_termination Status_of_leaving  \
# 0  ...       Graduation    21-01-2021                  NaN            Salary
# 1  ...       Graduation    13-03-2021                  NaN     Work Accident
#
#    Mode_of_work  Leaves  Absenteeism  Work_accident  Source_of_Hire   Job_mode
# 0        OFFICE       4            2             No       Job Event   Contract
# 1           WFH       5            2             No       Recruiter  Part Time
#
# [2 rows x 32 columns]

# %%
# New shape of data file.
df.shape
# Out:
# (1470, 32)

# %% [markdown]
# ## 1. Travelling  detail of employee

# %%
# Travelling  detail of employee

Travel_details = df['BusinessTravel'].value_counts().reset_index()
Travel_details
# Out:
#                index  BusinessTravel
# 0      Travel_Rarely            1043
# 1  Travel_Frequently             277
# 2         Non-Travel             150

# %%
fig, ax = plt.subplots(figsize=(10,6))
Travel_barplot= sns.barplot(data=Travel_details,x='index',y='BusinessTravel')
Travel_barplot.set(xlabel ="Type of Business Travel by employee", ylabel = "Counts", title ="Barplot for Business Travel")
plt.show()

# %% [markdown]
# ### Conslusion : Most of the employee are travelling rarely.

# %% [markdown]
# ##2. Working mode of employee

# %%
# WOrk mode of employee

work_mode =pd.DataFrame(df['Mode_of_work']).value_counts().reset_index()
work_mode
# Out:
#   Mode_of_work    0
# 0          WFH  768
# 1       OFFICE  702

# %%
work_mode.rename(columns = {0:'No of Employee'}, inplace = True)
work_mode
# Out:
#   Mode_of_work  No of Employee
# 0          WFH             768
# 1       OFFICE             702

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=work_mode, x='Mode_of_work', y='No of Employee')

# %% [markdown]
# ### Conclusion : Company have mostly equal count of employee that works WFH: Work From Home and WFO: Work From office

# %% [markdown]
# ##3.Reason why employee are leaving company

# %%
df.head(2)
# Out:
#    Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 0   37       Yes  Travel_Rarely  Research & Development                 2
# 1   21        No  Travel_Rarely  Research & Development                15
#
#   Gender  JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0   Male               2         1  Laboratory Technician                3
# 1   Male               3         1     Research Scientist                4
#
#    ... Higher_Education  Date_of_Hire  Date_of_termination Status_of_leaving  \
# 0  ...       Graduation    21-01-2021                  NaN            Salary
# 1  ...       Graduation    13-03-2021                  NaN     Work Accident
#
#    Mode_of_work  Leaves  Absenteeism  Work_accident  Source_of_Hire   Job_mode
# 0        OFFICE       4            2             No       Job Event   Contract
# 1           WFH       5            2             No       Recruiter  Part Time
#
# [2 rows x 32 columns]

# %%
# why employee are leaving company
leaving = pd.DataFrame(df['Status_of_leaving'].value_counts())
leaving
# Out:
#                     Status_of_leaving
# Dept.Head                         314
# Salary                            297
# Work Environment                  290
# Work Accident                     285
# Better Opportunity                284

# %%
leaving.rename(columns = {'Status_of_leaving':'Counts'},inplace=True)
leaving
# Out:
#                     Counts
# Dept.Head              314
# Salary                 297
# Work Environment       290
# Work Accident          285
# Better Opportunity     284

# %%
explode_val = (0.1,0,0,0,0)

# %%
plt.pie(leaving,labels =leaving.index,autopct='%1.1f%%',explode=explode_val)
# Out:
# <ipython-input-135-1760e606c081>:1: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   plt.pie(leaving,labels =leaving.index,autopct='%1.1f%%',explode=explode_val)
# ([<matplotlib.patches.Wedge at 0x7f5b95ade160>,
# ...
#  [Text(0.939794600529744, 0.7461810161181662, 'Dept.Head'),
#   Text(-0.43448827589425687, 1.0105542727189056, 'Salary'),
#   Text(-1.0955717146903945, -0.0986033365071852, 'Work Environment'),
#   Text(-0.2744694724465127, -1.065207260909788, 'Work Accident'),
#   Text(0.9035324363780183, -0.6273987060974883, 'Better Opportunity')],
#  [Text(0.5482135169756839, 0.43527225940226355, '21.4%'),
#   Text(-0.236993605033231, 0.5512114214830394, '20.2%'),
#   Text(-0.597584571649306, -0.053783638094828286, '19.7%'),
#   Text(-0.14971062133446147, -0.5810221423144297, '19.4%'),
#   Text(0.4928358743880099, -0.3422174760531754, '19.3%')])

# %% [markdown]
# ### Conclusion : More than 40% of employee are leaving company because lo Dept. Head and low salary .

# %%
df.head(2)
# Out:
#    Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 0   37       Yes  Travel_Rarely  Research & Development                 2
# 1   21        No  Travel_Rarely  Research & Development                15
#
#   Gender  JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0   Male               2         1  Laboratory Technician                3
# 1   Male               3         1     Research Scientist                4
#
#    ... Higher_Education  Date_of_Hire  Date_of_termination Status_of_leaving  \
# 0  ...       Graduation    21-01-2021                  NaN            Salary
# 1  ...       Graduation    13-03-2021                  NaN     Work Accident
#
#    Mode_of_work  Leaves  Absenteeism  Work_accident  Source_of_Hire   Job_mode
# 0        OFFICE       4            2             No       Job Event   Contract
# 1           WFH       5            2             No       Recruiter  Part Time
#
# [2 rows x 32 columns]

# %% [markdown]
# ##4. Job level according to age

# %%
#  Job levels according to age
job_level_df = df[['TotalWorkingYears','JobLevel']]
job_level_df
# Out:
#       TotalWorkingYears  JobLevel
# 0                     7         1
# 1                     0         1
# 2                    17         3
# 3                     3         1
# 4                     1         1
# ...                 ...       ...
# 1465                 34         4
# 1466                 37         5
# 1467                 36         5
# 1468                 38         4
# 1469                 40         3
#
# [1470 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Gender', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Higher_Education',
#        'Date_of_Hire', 'Date_of_termination', 'Status_of_leaving',
#        'Mode_of_work', 'Leaves', 'Absenteeism', 'Work_accident',
#        'Source_of_Hire', 'Job_mode'],
#       dtype='object')

# %%
# scatter plot  to show Job levels according to age
plt.scatter(x=df['TotalWorkingYears'],y=df['JobLevel'])

# %% [markdown]
# ### Conclusion : looking at the scatter plot we can conclude that job level of employee are near to equal in all job levels.

# %% [markdown]
# ##5. Expenditure on Salary of employee according to job role.

# %%
df.head(2)
# Out:
#    Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 0   37       Yes  Travel_Rarely  Research & Development                 2
# 1   21        No  Travel_Rarely  Research & Development                15
#
#   Gender  JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0   Male               2         1  Laboratory Technician                3
# 1   Male               3         1     Research Scientist                4
#
#    ... Higher_Education  Date_of_Hire  Date_of_termination Status_of_leaving  \
# 0  ...       Graduation    21-01-2021                  NaN            Salary
# 1  ...       Graduation    13-03-2021                  NaN     Work Accident
#
#    Mode_of_work  Leaves  Absenteeism  Work_accident  Source_of_Hire   Job_mode
# 0        OFFICE       4            2             No       Job Event   Contract
# 1           WFH       5            2             No       Recruiter  Part Time
#
# [2 rows x 32 columns]

# %%
# Monthly salary of Male and Female Employee according to Job role.
# Ploting using seaborn(sns) countplot
fig = plt.figure(figsize=(10,5))
sns.countplot(data=df['MonthlyIncome'], x = df['JobRole'],hue=df["Gender"])
plt.xlabel('JobRole', fontsize=12)
plt.xticks(rotation=90,fontsize=12);

# %% [markdown]
# ### Conclusion : Company has high expenditure on salary of sales Executive and Research Scientist. While human resources has lowest.

# %% [markdown]
# ## 6. Distance from company where employee stays.

# %%
distance = pd.DataFrame(df['DistanceFromHome'].value_counts())
distance
# Out:
#     DistanceFromHome
# 2                211
# 1                208
# 10                86
# 9                 85
# 3                 84
# 7                 84
# 8                 80
# 5                 65
# 4                 64
# 6                 59
# 16                32
# 11                29
# 24                28
# 29                27
# 23                27
# 18                26
# 15                26
# 20                25
# 25                25
# 26                25
# 28                23
# 19                22
# 14                21
# 12                20
# 17                20
# 22                19
# 13                19
# 21                18
# 27                12

# %%
plt.scatter(x=df['DistanceFromHome'],y=df.index)

# %% [markdown]
# ### Conclusion : As most of the data is spread between 0 to 10 , we can conclude that most of the employee stay less than 10 km from company.

# %%
df.head(2)
# Out:
#    Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 0   37       Yes  Travel_Rarely  Research & Development                 2
# 1   21        No  Travel_Rarely  Research & Development                15
#
#   Gender  JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0   Male               2         1  Laboratory Technician                3
# 1   Male               3         1     Research Scientist                4
#
#    ... Higher_Education  Date_of_Hire  Date_of_termination Status_of_leaving  \
# 0  ...       Graduation    21-01-2021                  NaN            Salary
# 1  ...       Graduation    13-03-2021                  NaN     Work Accident
#
#    Mode_of_work  Leaves  Absenteeism  Work_accident  Source_of_Hire   Job_mode
# 0        OFFICE       4            2             No       Job Event   Contract
# 1           WFH       5            2             No       Recruiter  Part Time
#
# [2 rows x 32 columns]
